# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in /azhome/eag007@ad.uit.no/.local/lib/python3.9/site-packages (4.9.2)

# %%
from bs4 import BeautifulSoup
import requests
import matplotlib.pyplot as plt
import numpy as np

def fetch_html_tables(url):
    page = requests.get(url)
    bs=BeautifulSoup(page.content)
    tables=bs.find_all('table')
    return tables

tables=fetch_html_tables('https://www.motor.no/aktuelt/motors-store-vintertest-av-rekkevidde-pa-elbiler/217132')
table_html=tables[0]

#printing top
print(str(table_html)[:1000])
# Out:
# <table class="" style="">
# <thead>
# <tr>
# <td>
#                 Modell (temp. varierte fra 0° til -10°)
#                 </td>
# <td>
#                 WLTP-tall
#                 </td>
# <td>
#                 STOPP
#                 </td>
# <td>
#                 Avvik
#                 </td>
# </tr>
# </thead>
# <tbody>
# <tr><td>Tesla Model 3 LR Dual motor</td><td>614 km/14,7 kWh</td><td>521 km</td><td>-15,15 %</td></tr>
# <tr><td>Mercedes-Benz EQS 580 4matic</td><td>645 km/18,3 kWh</td><td>513 km</td><td>-20,47 %</td></tr>
# <tr><td>BMW iX xDrive50</td><td>591 km/21,4 kWh</td><td>503 km</td><td>-14,89 %</td></tr>
# <tr><td>Tesla Model Y LR Dual motor</td><td>507 km/16,9 kWh</td><td>451 km</td><td>-11,05 %</td></tr>
# <tr><td>Volkswagen ID.3 PRO S</td><td>539 km/16,3 kWh</td><td>435 km</td><td>-19,29 %</td></tr>
# <tr><td>Kia EV6 2WD</td><td>528 km/16,5 kWh</td><td>429 km</td><td>-18,75 %</td></tr>
# <tr><td>NIO ES8 LR 7-seter</td><td>488 km/21,5 kWh</td><td>425 km</td><td>-12,91 %</td></tr>
# <tr><td>Kia EV6 4WD</td><td>484

# %%
def html_to_table(html):
    #defining the table:
    table=[]
    #iterating over all rows
    for row in html.find_all('tr'):
        r=[]
        #finding all cells in each row:
        cells=row.find_all('td')
        
        #if no cells are found, look for headings
        if len(cells)==0:
            cells=row.find_all('th')
            
        #iterate over cells:
        for cell in cells:
            cell=format(cell)
            r.append(cell)
        
        #append the row to t:
        table.append(r)
    return table
def format(cell):
    if cell.content is None:
        s=cell.text
    elif len(cell.content)==0:
        return ''
    else:
        s=' '.join([str(c) for c in cell.content])
        
    #here you can add additional characters/strings you want to 
    #remove, change punctuations or format the string in other
    #ways:
    s=s.replace('\xa0','')
    s=s.replace('\n','')
    return s

# %%
table=html_to_table(table_html)

#printing top
print(str(table)[:1000])
';'.join(table[0])
# Out:
# [['                Modell (temp. varierte fra 0° til -10°)                ', '                WLTP-tall                ', '                STOPP                ', '                Avvik                '], ['Tesla Model 3 LR Dual motor', '614 km/14,7 kWh', '521 km', '-15,15 %'], ['Mercedes-Benz EQS 580 4matic', '645 km/18,3 kWh', '513 km', '-20,47 %'], ['BMW iX xDrive50', '591 km/21,4 kWh', '503 km', '-14,89 %'], ['Tesla Model Y LR Dual motor', '507 km/16,9 kWh', '451 km', '-11,05 %'], ['Volkswagen ID.3 PRO S', '539 km/16,3 kWh', '435 km', '-19,29 %'], ['Kia EV6 2WD', '528 km/16,5 kWh', '429 km', '-18,75 %'], ['NIO ES8 LR 7-seter', '488 km/21,5 kWh', '425 km', '-12,91 %'], ['Kia EV6 4WD', '484 km/18,0 kWh', '423 km', '-12,60 %'], ['Volkswagen ID.4 Pro', '485 km/18,4 kWh', '414 km', '-14,64 %'], ['Hyundai Ioniq 5 2WD', '481 km/16,8 kWh', '408 km', '-15,18 %'], ['BMW i4 M50', '497 km/19,0 kWh', '406 km', '-18,31 %'], ['Skoda Enyaq iV80X', '477 km/18,2 kWh', '403 km', '-15,51 %'], ['Porsch
# '                Modell (temp. varierte fra 0° til -10°)                ;                WLTP-tall                ;                STOPP                ;                Avvik                '

# %%
def save_data(file_name,table):
    f=open(file_name,'w')
    for row in table:
        f.write(';'.join(row)+'\n')
    f.close()
    
    
save_data('motordata.csv',table)

# %%
import pandas as pd
df = pd.read_csv('motordata.csv', delimiter=';', encoding='latin1', on_bad_lines='skip')
df
# Out:
#                    Modell (temp. varierte fra 0Â° til -10Â°)                  \
# 0                         Tesla Model 3 LR Dual motor
# 1                        Mercedes-Benz EQS 580 4matic
# 2                                     BMW iX xDrive50
# 3                         Tesla Model Y LR Dual motor
# 4                               Volkswagen ID.3 PRO S
# 5                                         Kia EV6 2WD
# 6                                  NIO ES8 LR 7-seter
# 7                                         Kia EV6 4WD
# 8                                 Volkswagen ID.4 Pro
# 9                                 Hyundai Ioniq 5 2WD
# 10                                         BMW i4 M50
# 11                                  Skoda Enyaq iV80X
# 12                     Porsche Taycan 4 Cross Turismo
# 13                         Polestar 2 LR Single motor
# 14                                     Audi e-tron GT
# 15                                           Xpeng P7
# 16                                  Audi e-tron Q4 40
# 17                    Hyundai Ioniq 5 4WD (19-tommer)
# 18                 Hyundai Ioniq 5 LR 4WD (20-tommer)
# 19                                           BYD Tang
# 20                                Volkswagen ID.4 GTX
# 21                          Audi e-tron Q4 50 quattro
# 22                                   Skoda Enyaq iV80
# 23                                   Tesla Model 3 SR
# 24                           Polestar 2 LR Dual motor
# 25               Polestar 2 LR Dual motor (m bagasje)
# 26                                         Cupra Born
# 27                                 Volvo C40 Recharge
# 28                              Mercedes-Benz EQA 250
# 29                                    BMW iX xDrive40
# 30                       Mercedes-Benz EQB 350 4matic
# 31                                       Opel Mokka-e
# 32                                     Peugeot e-2008
#
#                    WLTP-tall                  \
# 0                            614 km/14,7 kWh
# 1                            645 km/18,3 kWh
# 2                            591 km/21,4 kWh
# 3                            507 km/16,9 kWh
# 4                            539 km/16,3 kWh
# 5                            528 km/16,5 kWh
# 6                            488 km/21,5 kWh
# 7                            484 km/18,0 kWh
# 8                            485 km/18,4 kWh
# 9                            481 km/16,8 kWh
# 10                           497 km/19,0 kWh
# 11                           477 km/18,2 kWh
# 12                           456 km/22,4 kWh
# 13                           517 km/18,6 kWh
# 14                           463 km/21,1 kWh
# 15                           470 km/19,4 kWh
# 16                           485 km/18,6 kWh
# 17                           460 km/17,7 kWh
# 18                           430 km/17,7 kWh
# 19                           400 km/21,6 kWh
# 20                           466 km/18,6 kWh
# 21                           459 km/19,1 kWh
# 22                           509 km/17,7 kWh
# 23                           448 km/14,0 kWh
# 24                           476 km/20,2 kWh
# 25                           470 km/19,5 kWh
# 26                           395 km/15,4 kWh
# 27                           437 km/21,1 kWh
# 28                           401 km/17,7 kWh
# 29                           402 km/20,7 kWh
# 30                           407 km/18,1 kWh
# 31                           338 km/16,2 kWh
# 32                           320 km/15,6 kWh
#
#                    STOPP                                 Avvik
# 0                                 521 km                              -15,15 %
# 1                                 513 km                              -20,47 %
# 2                                 503 km                              -14,89 %
# 3                                 451 km                              -11,05 %
# 4                                 435 km                              -19,29 %
# 5                                 429 km                              -18,75 %
# 6                                 425 km                              -12,91 %
# 7                                 423 km                              -12,60 %
# 8                                 414 km                              -14,64 %
# 9                                 408 km                              -15,18 %
# 10                                406 km                              -18,31 %
# 11                                403 km                              -15,51 %
# 12                                402 km                              -11,84 %
# 13                                400 km                              -22,63 %
# 14                                392 km                              -15,33 %
# 15                                383 km                              -18,51 %
# 16                                380 km                              -21,65 %
# 17                                369 km                              -19,78 %
# 18                                     x                                     x
# 19                                356 km                              -11,00 %
# 20                                353 km                              -24,20 %
# 21                                349 km                              -23,97 %
# 22                                347 km                              -31,83 %
# 23                                346 km                              -22,87 %
# 24                                340 km                              -28,57 %
# 25                                     x                                     x
# 26                                339 km                              -14,18 %
# 27                                333 km                              -23,80 %
# 28                                331 km                              -17,46 %
# 29                                316 km                              -21,39 %
# 30                                315 km                              -22,60 %
# 31                                263 km                              -22,19 %
# 32                                228 km                              -28,75 %

# %%
df = df.rename(columns={"                WLTP-tall                ": "WLTP"})
df = df.rename(columns={"                STOPP                ": "STOPP (km)","                Avvik                ": "Avvik (%)"})
df = df.drop([18, 25])
df
# Out:
#                    Modell (temp. varierte fra 0Â° til -10Â°)                  \
# 0                         Tesla Model 3 LR Dual motor
# 1                        Mercedes-Benz EQS 580 4matic
# 2                                     BMW iX xDrive50
# 3                         Tesla Model Y LR Dual motor
# 4                               Volkswagen ID.3 PRO S
# 5                                         Kia EV6 2WD
# 6                                  NIO ES8 LR 7-seter
# 7                                         Kia EV6 4WD
# 8                                 Volkswagen ID.4 Pro
# 9                                 Hyundai Ioniq 5 2WD
# 10                                         BMW i4 M50
# 11                                  Skoda Enyaq iV80X
# 12                     Porsche Taycan 4 Cross Turismo
# 13                         Polestar 2 LR Single motor
# 14                                     Audi e-tron GT
# 15                                           Xpeng P7
# 16                                  Audi e-tron Q4 40
# 17                    Hyundai Ioniq 5 4WD (19-tommer)
# 19                                           BYD Tang
# 20                                Volkswagen ID.4 GTX
# 21                          Audi e-tron Q4 50 quattro
# 22                                   Skoda Enyaq iV80
# 23                                   Tesla Model 3 SR
# 24                           Polestar 2 LR Dual motor
# 26                                         Cupra Born
# 27                                 Volvo C40 Recharge
# 28                              Mercedes-Benz EQA 250
# 29                                    BMW iX xDrive40
# 30                       Mercedes-Benz EQB 350 4matic
# 31                                       Opel Mokka-e
# 32                                     Peugeot e-2008
#
#                WLTP STOPP (km) Avvik (%)
# 0   614 km/14,7 kWh     521 km  -15,15 %
# 1   645 km/18,3 kWh     513 km  -20,47 %
# 2   591 km/21,4 kWh     503 km  -14,89 %
# 3   507 km/16,9 kWh     451 km  -11,05 %
# 4   539 km/16,3 kWh     435 km  -19,29 %
# 5   528 km/16,5 kWh     429 km  -18,75 %
# 6   488 km/21,5 kWh     425 km  -12,91 %
# 7   484 km/18,0 kWh     423 km  -12,60 %
# 8   485 km/18,4 kWh     414 km  -14,64 %
# 9   481 km/16,8 kWh     408 km  -15,18 %
# 10  497 km/19,0 kWh     406 km  -18,31 %
# 11  477 km/18,2 kWh     403 km  -15,51 %
# 12  456 km/22,4 kWh     402 km  -11,84 %
# 13  517 km/18,6 kWh     400 km  -22,63 %
# 14  463 km/21,1 kWh     392 km  -15,33 %
# 15  470 km/19,4 kWh     383 km  -18,51 %
# 16  485 km/18,6 kWh     380 km  -21,65 %
# 17  460 km/17,7 kWh     369 km  -19,78 %
# 19  400 km/21,6 kWh     356 km  -11,00 %
# 20  466 km/18,6 kWh     353 km  -24,20 %
# 21  459 km/19,1 kWh     349 km  -23,97 %
# 22  509 km/17,7 kWh     347 km  -31,83 %
# 23  448 km/14,0 kWh     346 km  -22,87 %
# 24  476 km/20,2 kWh     340 km  -28,57 %
# 26  395 km/15,4 kWh     339 km  -14,18 %
# 27  437 km/21,1 kWh     333 km  -23,80 %
# 28  401 km/17,7 kWh     331 km  -17,46 %
# 29  402 km/20,7 kWh     316 km  -21,39 %
# 30  407 km/18,1 kWh     315 km  -22,60 %
# 31  338 km/16,2 kWh     263 km  -22,19 %
# 32  320 km/15,6 kWh     228 km  -28,75 %

# %%
df1=df

# %%
df[['WLTP-km', 'WLTP-kWh']] = df['WLTP'].str.split('/', expand=True)

# clean up new columns by removing units and converting to numeric
df['WLTP-km'] = df['WLTP-km'].str.replace(' km', '').astype(float)
df['WLTP-kWh'] = df['WLTP-kWh'].str.replace(' kWh', '').str.replace(',', '.').astype(float)

# display result
df
# Out:
#                    Modell (temp. varierte fra 0Â° til -10Â°)                  \
# 0                         Tesla Model 3 LR Dual motor
# 1                        Mercedes-Benz EQS 580 4matic
# 2                                     BMW iX xDrive50
# 3                         Tesla Model Y LR Dual motor
# 4                               Volkswagen ID.3 PRO S
# 5                                         Kia EV6 2WD
# 6                                  NIO ES8 LR 7-seter
# 7                                         Kia EV6 4WD
# 8                                 Volkswagen ID.4 Pro
# 9                                 Hyundai Ioniq 5 2WD
# 10                                         BMW i4 M50
# 11                                  Skoda Enyaq iV80X
# 12                     Porsche Taycan 4 Cross Turismo
# 13                         Polestar 2 LR Single motor
# 14                                     Audi e-tron GT
# 15                                           Xpeng P7
# 16                                  Audi e-tron Q4 40
# 17                    Hyundai Ioniq 5 4WD (19-tommer)
# 19                                           BYD Tang
# 20                                Volkswagen ID.4 GTX
# 21                          Audi e-tron Q4 50 quattro
# 22                                   Skoda Enyaq iV80
# 23                                   Tesla Model 3 SR
# 24                           Polestar 2 LR Dual motor
# 26                                         Cupra Born
# 27                                 Volvo C40 Recharge
# 28                              Mercedes-Benz EQA 250
# 29                                    BMW iX xDrive40
# 30                       Mercedes-Benz EQB 350 4matic
# 31                                       Opel Mokka-e
# 32                                     Peugeot e-2008
#
#                WLTP STOPP (km) Avvik (%)  WLTP-km  WLTP-kWh
# 0   614 km/14,7 kWh     521 km  -15,15 %    614.0      14.7
# 1   645 km/18,3 kWh     513 km  -20,47 %    645.0      18.3
# 2   591 km/21,4 kWh     503 km  -14,89 %    591.0      21.4
# 3   507 km/16,9 kWh     451 km  -11,05 %    507.0      16.9
# 4   539 km/16,3 kWh     435 km  -19,29 %    539.0      16.3
# 5   528 km/16,5 kWh     429 km  -18,75 %    528.0      16.5
# 6   488 km/21,5 kWh     425 km  -12,91 %    488.0      21.5
# 7   484 km/18,0 kWh     423 km  -12,60 %    484.0      18.0
# 8   485 km/18,4 kWh     414 km  -14,64 %    485.0      18.4
# 9   481 km/16,8 kWh     408 km  -15,18 %    481.0      16.8
# 10  497 km/19,0 kWh     406 km  -18,31 %    497.0      19.0
# 11  477 km/18,2 kWh     403 km  -15,51 %    477.0      18.2
# 12  456 km/22,4 kWh     402 km  -11,84 %    456.0      22.4
# 13  517 km/18,6 kWh     400 km  -22,63 %    517.0      18.6
# 14  463 km/21,1 kWh     392 km  -15,33 %    463.0      21.1
# 15  470 km/19,4 kWh     383 km  -18,51 %    470.0      19.4
# 16  485 km/18,6 kWh     380 km  -21,65 %    485.0      18.6
# 17  460 km/17,7 kWh     369 km  -19,78 %    460.0      17.7
# 19  400 km/21,6 kWh     356 km  -11,00 %    400.0      21.6
# 20  466 km/18,6 kWh     353 km  -24,20 %    466.0      18.6
# 21  459 km/19,1 kWh     349 km  -23,97 %    459.0      19.1
# 22  509 km/17,7 kWh     347 km  -31,83 %    509.0      17.7
# 23  448 km/14,0 kWh     346 km  -22,87 %    448.0      14.0
# 24  476 km/20,2 kWh     340 km  -28,57 %    476.0      20.2
# 26  395 km/15,4 kWh     339 km  -14,18 %    395.0      15.4
# 27  437 km/21,1 kWh     333 km  -23,80 %    437.0      21.1
# 28  401 km/17,7 kWh     331 km  -17,46 %    401.0      17.7
# 29  402 km/20,7 kWh     316 km  -21,39 %    402.0      20.7
# 30  407 km/18,1 kWh     315 km  -22,60 %    407.0      18.1
# 31  338 km/16,2 kWh     263 km  -22,19 %    338.0      16.2
# 32  320 km/15,6 kWh     228 km  -28,75 %    320.0      15.6

# %%
df = df.drop(columns=['WLTP'])
df['STOPP (km)'] = df['STOPP (km)'].str.replace(' km', '').astype(float)
df['Avvik (%)'] = df['Avvik (%)'].str.replace(',', '.').str.replace('%', '').astype(float)
df
# Out:
#                    Modell (temp. varierte fra 0Â° til -10Â°)                  \
# 0                         Tesla Model 3 LR Dual motor
# 1                        Mercedes-Benz EQS 580 4matic
# 2                                     BMW iX xDrive50
# 3                         Tesla Model Y LR Dual motor
# 4                               Volkswagen ID.3 PRO S
# 5                                         Kia EV6 2WD
# 6                                  NIO ES8 LR 7-seter
# 7                                         Kia EV6 4WD
# 8                                 Volkswagen ID.4 Pro
# 9                                 Hyundai Ioniq 5 2WD
# 10                                         BMW i4 M50
# 11                                  Skoda Enyaq iV80X
# 12                     Porsche Taycan 4 Cross Turismo
# 13                         Polestar 2 LR Single motor
# 14                                     Audi e-tron GT
# 15                                           Xpeng P7
# 16                                  Audi e-tron Q4 40
# 17                    Hyundai Ioniq 5 4WD (19-tommer)
# 19                                           BYD Tang
# 20                                Volkswagen ID.4 GTX
# 21                          Audi e-tron Q4 50 quattro
# 22                                   Skoda Enyaq iV80
# 23                                   Tesla Model 3 SR
# 24                           Polestar 2 LR Dual motor
# 26                                         Cupra Born
# 27                                 Volvo C40 Recharge
# 28                              Mercedes-Benz EQA 250
# 29                                    BMW iX xDrive40
# 30                       Mercedes-Benz EQB 350 4matic
# 31                                       Opel Mokka-e
# 32                                     Peugeot e-2008
#
#     STOPP (km)  Avvik (%)  WLTP-km  WLTP-kWh
# 0        521.0     -15.15    614.0      14.7
# 1        513.0     -20.47    645.0      18.3
# 2        503.0     -14.89    591.0      21.4
# 3        451.0     -11.05    507.0      16.9
# 4        435.0     -19.29    539.0      16.3
# 5        429.0     -18.75    528.0      16.5
# 6        425.0     -12.91    488.0      21.5
# 7        423.0     -12.60    484.0      18.0
# 8        414.0     -14.64    485.0      18.4
# 9        408.0     -15.18    481.0      16.8
# 10       406.0     -18.31    497.0      19.0
# 11       403.0     -15.51    477.0      18.2
# 12       402.0     -11.84    456.0      22.4
# 13       400.0     -22.63    517.0      18.6
# 14       392.0     -15.33    463.0      21.1
# 15       383.0     -18.51    470.0      19.4
# 16       380.0     -21.65    485.0      18.6
# 17       369.0     -19.78    460.0      17.7
# 19       356.0     -11.00    400.0      21.6
# 20       353.0     -24.20    466.0      18.6
# 21       349.0     -23.97    459.0      19.1
# 22       347.0     -31.83    509.0      17.7
# 23       346.0     -22.87    448.0      14.0
# 24       340.0     -28.57    476.0      20.2
# 26       339.0     -14.18    395.0      15.4
# 27       333.0     -23.80    437.0      21.1
# 28       331.0     -17.46    401.0      17.7
# 29       316.0     -21.39    402.0      20.7
# 30       315.0     -22.60    407.0      18.1
# 31       263.0     -22.19    338.0      16.2
# 32       228.0     -28.75    320.0      15.6

# %%
import numpy as np
X = df['WLTP-km'].values
Y = df['STOPP (km)'].values
a, b = np.polyfit(X, Y, 1)

x = np.linspace (0, 800, 100)
fig,ax=plt.subplots()
ax.set_xlim(0,800)
ax.set_ylim(0,800)

ax.scatter(X,Y, label='Observasjoner')
ax.plot(x,x,label='leverandørlovnad', color = 'green')

plt.plot(x, a*x + b, color='red', label='Regresjonsmodell')
plt.legend()
plt.show()
